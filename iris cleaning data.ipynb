# %%
import pandas as pd 
import numpy as np

# %%
# Display Dataset
iris_data = pd.read_csv('iris(raw data).csv')
iris_data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa
# 9           4.9          3.1           1.5          0.1  setosa

# %%
# Check Missing Values
missing_values = iris_data.isnull().sum()
print (missing_values)
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
# Check duplicated Values
num_duplicates = iris_data.duplicated().sum()
print("Number of duplicate rows:", num_duplicates)
# Out:
# Number of duplicate rows: 3

# %%
import pandas as pd 
import numpy as np

# %%
iris_data = pd.read_csv('iris(raw data).csv')

# %%
# remove duplicated Values
iris_data = iris_data .drop_duplicates()

# %%
print( iris_data.duplicated().sum())
# Out:
# 0

# %%
# Check data types
print(iris_data.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# Check unique categorical variables in other to standardize them
print(iris_data["species"].unique())
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
iris_data.to_csv("Cleaned_Iris_Dataset.csv", index=False)
